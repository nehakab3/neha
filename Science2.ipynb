# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("C:/Users/user/Documents/PythonforDataScience/tips.xlsx")

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.tail(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
day=df.groupby(['day']).sum()
day
# Out:
#       total_bill     tip                                                sex  \
# day
# Fri       325.88   51.96  MaleMaleFemaleFemaleFemaleMaleMaleMaleMaleMale...
# Sat      1778.40  260.40  MaleMaleFemaleFemaleMaleMaleMaleMaleMaleMaleFe...
# Sun      1627.16  247.39  FemaleMaleMaleMaleFemaleMaleMaleMaleMaleMaleMa...
# Thur     1096.33  171.83  MaleMaleMaleMaleMaleFemaleMaleMaleFemaleMaleMa...
#
#                                                  smoker  \
# day
# Fri   YesNoYesYesNoYesYesYesYesNoYesYesYesYesYesNoYe...
# Sat   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoYe...
# Sun   NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# Thur  NoNoNoYesNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
#
#                                                    time  size
# day
# Fri   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...    40
# Sat   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   219
# Sun   DinnerDinnerDinnerDinnerDinnerDinnerDinnerDinn...   216
# ...

# %%
df['tip'].mean()
# Out:
# 2.99827868852459

# %%
df['%tips']=(df['tip']/df['total_bill']*100)
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size      %tips
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159

# %%
#style.format({'%tips':'{:,.0f}'})

# %%
df['bill']=(df['total_bill']/df['size'])
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size      %tips      bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673  8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159  3.446667

# %%
df['day_type']=np.where(df['day'].isin(['Sat','Sun']),'weekend','weekday')
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size      %tips      bill  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673  8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159  3.446667
#
#   day_type
# 0  weekend
# 1  weekend

# %%
df.shape
# Out:
# (244, 10)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size      %tips       bill  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673   8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159   3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734   7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041  11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765   6.147500
#
#   day_type
# 0  weekend
# 1  weekend
# 2  weekend
# 3  weekend
# 4  weekend

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
#  7   %tips       244 non-null    float64
#  8   bill        244 non-null    float64
#  9   day_type    244 non-null    object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 19.2+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size       %tips       bill
# count  244.000000  244.000000  244.000000  244.000000  244.00000
# mean    19.785943    2.998279    2.569672   16.080258    7.88823
# std      8.902412    1.383638    0.951100    6.107220    2.91435
# min      3.070000    1.000000    1.000000    3.563814    2.87500
# 25%     13.347500    2.000000    2.000000   12.912736    5.80250
# 50%     17.795000    2.900000    2.000000   15.476977    7.25500
# 75%     24.127500    3.562500    3.000000   19.147549    9.39000
# max     50.810000   10.000000    6.000000   71.034483   20.27500

# %%
df['%tips'].median()
# Out:
# 15.476977125802577

# %%
df.groupby('sex').agg({'%tips':'median'})
# Out:
#             %tips
# sex
# Female  15.558149
# Male    15.349194

# %%
mct = df['total_bill'].count()
msum = df['total_bill'].sum()
mmean = df['total_bill'].mean()
msd = df['total_bill'].std()
mmin = df['total_bill'].min()
mq1 = df['total_bill'].quantile(0.25)
mmid = df['total_bill'].median()
mq3 = df['total_bill'].quantile(0.75)
mmax = df['total_bill'].max()
mran = df['total_bill'].max() - df['total_bill'].min()
miqr = df['total_bill'].quantile(0.75) - df['total_bill'].quantile(0.25)
mlow = df['total_bill'].quantile(0.25) - (1.5 * (df['total_bill'].quantile(0.75) - df['total_bill'].quantile(0.25)))
mup = df['total_bill'].quantile(0.75) + (1.5 * (df['total_bill'].quantile(0.75) - df['total_bill'].quantile(0.25)))
mvar = df['total_bill'].var()
mcoff = df['total_bill'].std() / df['total_bill'].mean() * 100
mskew = df['total_bill'].skew()
mkurt = df['total_bill'].kurtosis()

# %%
print(mct)
print(msum)
print(mmean)
print(msd)
print(mmin)
print(mq1)
print(mmid)
print(mq3)
print(mmax)
print(mran)
print(miqr)
print(mlow)
print(mup)
print(mvar)
print(mcoff)
print(mskew)
print(mkurt)
# Out:
# 244
# 4827.77
# 19.78594262295082
# 8.902411954856856
# 3.07
# 13.3475
# 17.795
# 24.127499999999998
# 50.81
# 47.74
# 10.779999999999998
# -2.8224999999999945
# 40.29749999999999
# 79.25293861397826
# 44.99362059470673
# 1.1332130376158205
# 1.2184840156638854

# %%
Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
Total_bill = [244,4827.77,19.78594262295082,8.902411954856856,3.07,13.3475,17.795,24.127499999999998,50.81,47.74,10.779999999999998,-2.8224999999999945,40.29749999999999,79.25293861397826,44.99362059470673,1.1332130376158205,1.2184840156638854]

data = pd.DataFrame([Metric,Total_bill]) # Each list would be added as a row
data = data.transpose() # To Transpose and make each rows as columns
data.columns = ['Metric', 'Total_bill'] # Rename the columns
data
# Out:
#    Metric Total_bill
# 0      ct        244
# 1     sum    4827.77
# 2    mean  19.785943
# 3      sd   8.902412
# 4     min       3.07
# 5      q1    13.3475
# 6     mid     17.795
# 7      q3    24.1275
# 8     max      50.81
# 9     ran      47.74
# 10    iqr      10.78
# 11    low    -2.8225
# 12     up    40.2975
# 13    var  79.252939
# 14   coff  44.993621
# 15   skew   1.133213
# 16   kurt   1.218484

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['total_bill'], kde=True, bins=7)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17184\1359265307.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'], kde=True, bins=7)

# %% [markdown]
# ### ON TOTAL_BILL WEEKDAY, WEEKEND

# %%
days=df.groupby('day_type').describe()
days
# Out:
#          total_bill                                                           \
#               count       mean       std   min     25%    50%     75%    max
# day_type
# weekday        81.0  17.558148  7.936160  5.75  12.260  15.98  20.530  43.11
# weekend       163.0  20.893006  9.168543  3.07  14.605  18.35  25.285  50.81
#
#             tip            ...      %tips              bill            \
#           count      mean  ...        75%        max  count      mean
# day_type                   ...
# weekday    81.0  2.762840  ...  19.361084  26.631158   81.0  7.589790
# weekend   163.0  3.115276  ...  18.827082  71.034483  163.0  8.036534
#
#
#                std    min    25%    50%       75%     max
# day_type
# weekday   2.604791  2.875  5.845  6.800  8.735000  16.340
# weekend   3.053343  3.070  5.800  7.415  9.596667  20.275
#
# [2 rows x 40 columns]

# %%
df_weekday = df[df['day_type'] == 'weekday']
df_weekday.head(2)
# Out:
#     total_bill  tip   sex smoker   day   time  size      %tips   bill day_type
# 77       27.20  4.0  Male     No  Thur  Lunch     4  14.705882   6.80  weekday
# 78       22.76  3.0  Male     No  Thur  Lunch     2  13.181019  11.38  weekday

# %%
df_weekend = df[df['day_type'] == 'weekend']
df_weekend.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size      %tips      bill  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673  8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159  3.446667
#
#   day_type
# 0  weekend
# 1  weekend

# %%
qmct = df_weekday['total_bill'].count()
qmsum = df_weekday['total_bill'].sum()
qmmean = df_weekday['total_bill'].mean()
qmsd = df_weekday['total_bill'].std()
qmmin = df_weekday['total_bill'].min()
qmq1 = df_weekday['total_bill'].quantile(0.25)
qmmid = df_weekday['total_bill'].median()
qmq3 = df_weekday['total_bill'].quantile(0.75)
qmmax = df_weekday['total_bill'].max()
qmran = df_weekday['total_bill'].max() - df_weekday['total_bill'].min()
qmiqr = df_weekday['total_bill'].quantile(0.75) - df_weekday['total_bill'].quantile(0.25)
qmlow = df_weekday['total_bill'].quantile(0.25) - (1.5 * (df_weekday['total_bill'].quantile(0.75) - df_weekday['total_bill'].quantile(0.25)))
qmup = df_weekday['total_bill'].quantile(0.75) + (1.5 * (df_weekday['total_bill'].quantile(0.75) - df_weekday['total_bill'].quantile(0.25)))
qmvar = df_weekday['total_bill'].var()
qmcoff = df_weekday['total_bill'].std() / df_weekday['total_bill'].mean() * 100
qmskew = df_weekday['total_bill'].skew()
qmkurt = df_weekday['total_bill'].kurtosis()

# %%
print(qmct)
print(qmsum)
print(qmmean)
print(qmsd)
print(qmmin)
print(qmq1)
print(qmmid)
print(qmq3)
print(qmmax)
print(qmran)
print(qmiqr)
print(qmlow)
print(qmup)
print(qmvar)
print(qmcoff)
print(qmskew)
print(qmkurt)
# Out:
# 81
# 1422.21
# 17.55814814814815
# 7.936159825619554
# 5.75
# 12.26
# 15.98
# 20.53
# 43.11
# 37.36
# 8.270000000000001
# -0.14500000000000135
# 32.935
# 62.982632777777795
# 45.19929868832197
# 1.3189448045316583
# 1.6591678326947035

# %%
Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
Weekday = [81,1422.21,17.55814814814815,7.936159825619554,5.75,12.26,15.98,20.53,43.11,37.36,8.270000000000001,-0.14500000000000135,32.935,62.982632777777795,45.19929868832197,1.3189448045316583,1.6591678326947035]

wd = pd.DataFrame([Metric,Weekday]) # Each list would be added as a row
wd = wd.transpose() # To Transpose and make each rows as columns
wd.columns = ['Metric', 'Weekday'] # Rename the columns
wd
# Out:
#    Metric    Weekday
# 0      ct         81
# 1     sum    1422.21
# 2    mean  17.558148
# 3      sd    7.93616
# 4     min       5.75
# 5      q1      12.26
# 6     mid      15.98
# 7      q3      20.53
# 8     max      43.11
# 9     ran      37.36
# 10    iqr       8.27
# 11    low     -0.145
# 12     up     32.935
# 13    var  62.982633
# 14   coff  45.199299
# 15   skew   1.318945
# 16   kurt   1.659168

# %%
wmct = df_weekend['%tips'].count()
wmsum = df_weekend['%tips'].sum()
wmmean = df_weekend['%tips'].mean()
wmsd = df_weekend['%tips'].std()
wmmin = df_weekend['%tips'].min()
wmq1 = df_weekend['%tips'].quantile(0.25)
wmmid = df_weekend['%tips'].median()
wmq3 = df_weekend['%tips'].quantile(0.75)
wmmax = df_weekend['%tips'].max()
wmran = df_weekend['%tips'].max() - df_weekend['%tips'].min()
wmiqr = df_weekend['%tips'].quantile(0.75) - df_weekend['%tips'].quantile(0.25)
wmlow = df_weekend['%tips'].quantile(0.25) - (1.5 * (df_weekend['%tips'].quantile(0.75) - df_weekend['%tips'].quantile(0.25)))
wmup = df_weekend['%tips'].quantile(0.75) + (1.5 * (df_weekend['%tips'].quantile(0.75) - df_weekend['%tips'].quantile(0.25)))
wmvar = df_weekend['%tips'].var()
wmcoff = df_weekend['%tips'].std() / df_weekend['%tips'].mean() * 100
wmskew = df_weekend['%tips'].skew()
wmkurt = df_weekend['%tips'].kurtosis()

# %%
print(wmct)
print(wmsum)
print(wmmean)
print(wmsd)
print(wmmin)
print(wmq1)
print(wmmid)
print(wmq3)
print(wmmax)
print(wmran)
print(wmiqr)
print(wmlow)
print(wmup)
print(wmvar)
print(wmcoff)
print(wmskew)
print(wmkurt)
# Out:
# 163
# 2600.839308842293
# 15.95606937940057
# 6.905334821735154
# 3.563813585135547
# 12.300239310006502
# 15.558148580318942
# 18.827081506393377
# 71.0344827586207
# 67.47066917348515
# 6.526842196386875
# 2.5099760154261883
# 28.61734480097369
# 47.68364900026806
# 43.27716718661303
# 3.487808584260595
# 25.039822349231244

# %%
Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
webill = [81,1422.21,17.55814814814815,7.936159825619554,5.75,12.26,15.98,20.53,43.11,37.36,8.270000000000001,-0.14500000000000135,32.935,62.982632777777795,45.19929868832197,1.3189448045316583,1.6591678326947035]
wdbill = [163,3405.5600000000004,20.893006134969326,9.168543184020356,3.07,14.605,18.35,25.285,50.81,47.74,10.68,-1.4149999999999991,41.305,84.06218411724612,43.883312553451354,1.057164102540653,1.0773542784248868 ] 
wdwee = pd.DataFrame([Metric, webill, wdbill]) # Each list would be added as a row
wdwee = wdwee.transpose() # To Transpose and make each rows as columns
wdwee.columns = ['Metric','wdbill','wdbill'] # Rename the columns
wdwee
# Out:
#    Metric     wdbill     wdbill
# 0      ct         81        163
# 1     sum    1422.21    3405.56
# 2    mean  17.558148  20.893006
# 3      sd    7.93616   9.168543
# 4     min       5.75       3.07
# 5      q1      12.26     14.605
# 6     mid      15.98      18.35
# 7      q3      20.53     25.285
# 8     max      43.11      50.81
# 9     ran      37.36      47.74
# 10    iqr       8.27      10.68
# 11    low     -0.145     -1.415
# 12     up     32.935     41.305
# 13    var  62.982633  84.062184
# 14   coff  45.199299  43.883313
# 15   skew   1.318945   1.057164
# 16   kurt   1.659168   1.077354

# %%
sns.displot(data=df, x='total_bill', col='day_type', kde=True, bins=5)

plt.suptitle('Distribution of Total Bill by day_type', y=1.05)
plt.show()

# %% [markdown]
# ### ON TOTAL_BILL MALE, FEMALE

# %%
df_Male = df[df['sex'] == 'Male']
df_Male.head(2)
# Out:
#    total_bill   tip   sex smoker  day    time  size      %tips      bill  \
# 1       10.34  1.66  Male     No  Sun  Dinner     3  16.054159  3.446667
# 2       21.01  3.50  Male     No  Sun  Dinner     3  16.658734  7.003333
#
#   day_type
# 1  weekend
# 2  weekend

# %%
df_Female = df[df['sex'] == 'Female']
df_Female.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size      %tips    bill  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673  8.4950
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765  6.1475
#
#   day_type
# 0  weekend
# 4  weekend

# %%
emct = df_Male['total_bill'].count()
emsum = df_Male['total_bill'].sum()
emmean = df_Male['total_bill'].mean()
emsd = df_Male['total_bill'].std()
emmin = df_Male['total_bill'].min()
emq1 = df_Male['total_bill'].quantile(0.25)
emmid = df_Male['total_bill'].median()
emq3 = df_Male['total_bill'].quantile(0.75)
emmax = df_Male['total_bill'].max()
emran = df_Male['total_bill'].max() - df_Male['total_bill'].min()
emiqr = df_Male['total_bill'].quantile(0.75) - df_Male['total_bill'].quantile(0.25)
emlow = df_Male['total_bill'].quantile(0.25) - (1.5 * (df_Male['total_bill'].quantile(0.75) - df_Male['total_bill'].quantile(0.25)))
emup = df_Male['total_bill'].quantile(0.75) + (1.5 * (df_Male['total_bill'].quantile(0.75) - df_Male['total_bill'].quantile(0.25)))
emvar = df_Male['total_bill'].var()
emcoff = df_Male['total_bill'].std() / df_Male['total_bill'].mean() * 100
emskew = df_Male['total_bill'].skew()
emkurt = df_Male['total_bill'].kurtosis()

# %%
print(emct)
print(emsum)
print(emmean)
print(emsd)
print(emmin)
print(emq1)
print(emmid)
print(emq3)
print(emmax)
print(emran)
print(emiqr)
print(emlow)
print(emup)
print(emvar)
print(emcoff)
print(emskew)
print(emkurt)
# Out:
# 157
# 3256.8199999999997
# 20.744076433121016
# 9.24646876154476
# 7.25
# 14.0
# 18.35
# 24.71
# 50.81
# 43.56
# 10.71
# -2.0650000000000013
# 40.775000000000006
# 85.4971845582231
# 44.57401992012232
# 1.103269291396764
# 1.0527792077485825

# %%
amct = df_Female['total_bill'].count()
amsum = df_Female['total_bill'].sum()
ammean = df_Female['total_bill'].mean()
amsd = df_Female['total_bill'].std()
ammin = df_Female['total_bill'].min()
amq1 = df_Female['total_bill'].quantile(0.25)
ammid = df_Female['total_bill'].median()
amq3 = df_Female['total_bill'].quantile(0.75)
ammax = df_Female['total_bill'].max()
amran = df_Female['total_bill'].max() - df_Female['total_bill'].min()
amiqr = df_Female['total_bill'].quantile(0.75) - df_Female['total_bill'].quantile(0.25)
amlow = df_Female['total_bill'].quantile(0.25) - (1.5 * (df_Female['total_bill'].quantile(0.75) - df_Female['total_bill'].quantile(0.25)))
amup = df_Female['total_bill'].quantile(0.75) + (1.5 * (df_Female['total_bill'].quantile(0.75) - df_Female['total_bill'].quantile(0.25)))
amvar = df_Female['total_bill'].var()
amcoff = df_Female['total_bill'].std() / df_Female['total_bill'].mean() * 100
amskew = df_Female['total_bill'].skew()
amkurt = df_Female['total_bill'].kurtosis()

# %%
print(amct)
print(amsum)
print(ammean)
print(amsd)
print(ammin)
print(amq1)
print(ammid)
print(amq3)
print(ammax)
print(amran)
print(amiqr)
print(amlow)
print(amup)
print(amvar)
print(amcoff)
print(amskew)
print(amkurt)
# Out:
# 87
# 1570.9499999999996
# 18.056896551724133
# 8.009208988951961
# 3.07
# 12.75
# 16.4
# 21.520000000000003
# 44.3
# 41.23
# 8.770000000000003
# -0.4050000000000047
# 34.67500000000001
# 64.14742862870891
# 44.355401638423935
# 1.1340517317629666
# 1.3658254154894576

# %%
Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
Male = [157,3256.8199999999997,20.744076433121016,9.24646876154476,7.25,14.0,18.35,24.71,50.81,43.56,10.71,-2.0650000000000013,40.775000000000006,85.4971845582231,44.57401992012232,1.103269291396764,1.0527792077485825]
Female = [87,1570.9499999999996,18.056896551724133,8.009208988951961,3.07,12.75,16.4,21.520000000000003,44.3,41.23,8.770000000000003,-0.4050000000000047,34.67500000000001,64.14742862870891,44.355401638423935,1.1340517317629666,1.3658254154894576]
mf = pd.DataFrame([Metric, Male, Female]) # Each list would be added as a row
mf = mf.transpose() # To Transpose and make each rows as columns
mf.columns = ['Metric','Male','Female'] # Rename the columns
mf
# Out:
#    Metric       Male     Female
# 0      ct        157         87
# 1     sum    3256.82    1570.95
# 2    mean  20.744076  18.056897
# 3      sd   9.246469   8.009209
# 4     min       7.25       3.07
# 5      q1       14.0      12.75
# 6     mid      18.35       16.4
# 7      q3      24.71      21.52
# 8     max      50.81       44.3
# 9     ran      43.56      41.23
# 10    iqr      10.71       8.77
# 11    low     -2.065     -0.405
# 12     up     40.775     34.675
# 13    var  85.497185  64.147429
# 14   coff   44.57402  44.355402
# 15   skew   1.103269   1.134052
# 16   kurt   1.052779   1.365825

# %%
mf1 = mf.transpose()
mf1
# Out:
#          0        1          2         3     4      5      6      7      8   \
# Metric   ct      sum       mean        sd   min     q1    mid     q3    max
# Male    157  3256.82  20.744076  9.246469  7.25   14.0  18.35  24.71  50.81
# Female   87  1570.95  18.056897  8.009209  3.07  12.75   16.4  21.52   44.3
#
#            9      10     11      12         13         14        15        16
# Metric    ran    iqr    low      up        var       coff      skew      kurt
# Male    43.56  10.71 -2.065  40.775  85.497185   44.57402  1.103269  1.052779
# Female  41.23   8.77 -0.405  34.675  64.147429  44.355402  1.134052  1.365825

# %%
sns.distplot(df_Female['total_bill'], kde=True, bins=7)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17184\3524369082.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_Female['total_bill'], kde=True, bins=7)

# %%
sns.distplot(df_Male['total_bill'], kde=True, bins=7)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17184\4140728481.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_Male['total_bill'], kde=True, bins=7)

# %%
sns.displot(data=df, x='total_bill', col='sex', kde=True, bins=5)

plt.suptitle('Distribution of Total Bill by sex', y=1.05)
plt.show()

# %%
df.describe()
# Out:
#        total_bill         tip        size       %tips       bill
# count  244.000000  244.000000  244.000000  244.000000  244.00000
# mean    19.785943    2.998279    2.569672   16.080258    7.88823
# std      8.902412    1.383638    0.951100    6.107220    2.91435
# min      3.070000    1.000000    1.000000    3.563814    2.87500
# 25%     13.347500    2.000000    2.000000   12.912736    5.80250
# 50%     17.795000    2.900000    2.000000   15.476977    7.25500
# 75%     24.127500    3.562500    3.000000   19.147549    9.39000
# max     50.810000   10.000000    6.000000   71.034483   20.27500

# %% [markdown]
# ### ON TIPS - MALE, FEMALE

# %%
df = df['%tips']
df.head(2)
# Out:
# 0     5.944673
# 1    16.054159
# Name: %tips, dtype: float64

# %%
tct = df_Male['%tips'].count()
tsum = df_Male['%tips'].sum()
tmean = df_Male['%tips'].mean()
tsd = df_Male['%tips'].std()
tmmin = df_Male['%tips'].min()
tq1 = df_Male['%tips'].quantile(0.25)
tmid = df_Male['%tips'].median()
tq3 = df_Male['%tips'].quantile(0.75)
tmax = df_Male['%tips'].max()
tran = df_Male['%tips'].max() - df_Male['%tips'].min()
tiqr = df_Male['%tips'].quantile(0.75) - df_Male['%tips'].quantile(0.25)
tlow = df_Male['%tips'].quantile(0.25) - (1.5 * (df_Male['%tips'].quantile(0.75) - df_Male['%tips'].quantile(0.25)))
tup = df_Male['%tips'].quantile(0.75) + (1.5 * (df_Male['%tips'].quantile(0.75) - df_Male['%tips'].quantile(0.25)))
tvar = df_Male['%tips'].var()
tcoff = df_Male['%tips'].std() / df_Male['%tips'].mean() * 100
tskew = df_Male['%tips'].skew()
tkurt = df_Male['%tips'].kurtosis()

# %%
print(tct)
print(tsum)
print(tmean)
print(tsd)
print(tmmin)
print(tq1)
print(tmid)
print(tq3)
print(tmax)
print(tran)
print(tiqr)
print(tlow)
print(tup)
print(tvar)
print(tcoff)
print(tskew)
print(tkurt)
# Out:
# 157
# 2475.1135879674694
# 15.765054700429742
# 6.477787270951387
# 3.563813585135547
# 12.138868657441128
# 15.349194167306218
# 18.62396204033215
# 71.0344827586207
# 67.47066917348515
# 6.485093382891021
# 2.411228583104597
# 28.35160211466868
# 41.96172792769982
# 41.08953247574084
# 4.026231317945131
# 33.06373330037843

# %%
#Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
#Tips = [157,2475.1135879674694,15.765054700429742,6.477787270951387,3.563813585135547,12.138868657441128,15.349194167306218,18.62396204033215,71.0344827586207,67.47066917348515,6.485093382891021,2.411228583104597,28.35160211466868,41.96172792769982,41.08953247574084,4.026231317945131,33.06373330037843]

#tip1 = pd.DataFrame([Metric,Tips]) # Each list would be added as a row
#tip1 = tip1.transpose() # To Transpose and make each rows as columns
#tip1 .columns = ['Metric', 'Tips'] # Rename the columns
#tip1

# %%
#tips1 = tip1.transpose()
#tips1
# Out:
#          0            1          2         3         4          5          6   \
# Metric   ct          sum       mean        sd       min         q1        mid
# Tips    157  2475.113588  15.765055  6.477787  3.563814  12.138869  15.349194
#
#                7          8          9         10        11         12  \
# Metric         q3        max        ran       iqr       low         up
# Tips    18.623962  71.034483  67.470669  6.485093  2.411229  28.351602
#
#                13         14        15         16
# Metric        var       coff      skew       kurt
# Tips    41.961728  41.089532  4.026231  33.063733

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df_Male['%tips'], kde=True, bins=7)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17184\1831875196.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_Male['%tips'], kde=True, bins=7)

# %%
act = df_Female['%tips'].count()
asum = df_Female['%tips'].sum()
amean = df_Female['%tips'].mean()
asd = df_Female['%tips'].std()
ammin = df_Female['%tips'].min()
aq1 = df_Female['%tips'].quantile(0.25)
amid = df_Female['%tips'].median()
aq3 = df_Female['%tips'].quantile(0.75)
amax = df_Female['%tips'].max()
aran = df_Female['%tips'].max() - df_Female['%tips'].min()
aiqr = df_Female['%tips'].quantile(0.75) - df_Female['%tips'].quantile(0.25)
alow = df_Female['%tips'].quantile(0.25) - (1.5 * (df_Female['%tips'].quantile(0.75) - df_Female['%tips'].quantile(0.25)))
aup = df_Female['%tips'].quantile(0.75) + (1.5 * (df_Female['%tips'].quantile(0.75) - df_Female['%tips'].quantile(0.25)))
avar = df_Female['%tips'].var()
acoff = df_Female['%tips'].std() / df_Female['%tips'].mean() * 100
askew = df_Female['%tips'].skew()
akurt = df_Female['%tips'].kurtosis()

# %%
print(act)
print(asum)
print(amean)
print(asd)
print(ammin)
print(aq1)
print(amid)
print(aq3)
print(amax)
print(aran)
print(aiqr)
print(alow)
print(aup)
print(avar)
print(acoff)
print(askew)
print(akurt)
# Out:
# 87
# 1448.4694060616455
# 16.649073632892478
# 5.3631726229947505
# 5.643340857787811
# 14.04164487840004
# 15.558148580318942
# 19.42662127391307
# 41.66666666666667
# 36.02332580887886
# 5.38497639551303
# 5.964180285130494
# 27.504085867182617
# 28.763620584040392
# 32.21303924321101
# 1.332615101290936
# 5.430474603578114

# %%
Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
MaleT = [157,2475.1135879674694,15.765054700429742,6.477787270951387,3.563813585135547,12.138868657441128,15.349194167306218,18.62396204033215,71.0344827586207,67.47066917348515,6.485093382891021,2.411228583104597,28.35160211466868,41.96172792769982,41.08953247574084,4.026231317945131,33.06373330037843]
FemaleT = [87,1448.4694060616455,16.649073632892478,5.3631726229947505,5.643340857787811,14.04164487840004,15.558148580318942,19.42662127391307,41.66666666666667,36.02332580887886,5.38497639551303,5.964180285130494,27.504085867182617,28.763620584040392,32.21303924321101,1.332615101290936,5.430474603578114]

tip2 = pd.DataFrame([Metric,MaleT,FemaleT]) # Each list would be added as a row
tip2 = tip2.transpose() # To Transpose and make each rows as columns
tip2 .columns = ['Metric', 'MaleT','FemaleT'] # Rename the columns
tip2
# Out:
#    Metric        MaleT      FemaleT
# 0      ct          157           87
# 1     sum  2475.113588  1448.469406
# 2    mean    15.765055    16.649074
# 3      sd     6.477787     5.363173
# 4     min     3.563814     5.643341
# 5      q1    12.138869    14.041645
# 6     mid    15.349194    15.558149
# 7      q3    18.623962    19.426621
# 8     max    71.034483    41.666667
# 9     ran    67.470669    36.023326
# 10    iqr     6.485093     5.384976
# 11    low     2.411229      5.96418
# 12     up    28.351602    27.504086
# 13    var    41.961728    28.763621
# 14   coff    41.089532    32.213039
# 15   skew     4.026231     1.332615
# 16   kurt    33.063733     5.430475

# %%
tips2 = tip2.transpose()
tips2
# Out:
#           0            1          2         3         4          5   \
# Metric    ct          sum       mean        sd       min         q1
# MaleT    157  2475.113588  15.765055  6.477787  3.563814  12.138869
# FemaleT   87  1448.469406  16.649074  5.363173  5.643341  14.041645
#
#                 6          7          8          9         10        11  \
# Metric         mid         q3        max        ran       iqr       low
# MaleT    15.349194  18.623962  71.034483  67.470669  6.485093  2.411229
# FemaleT  15.558149  19.426621  41.666667  36.023326  5.384976   5.96418
#
#                 12         13         14        15         16
# Metric          up        var       coff      skew       kurt
# MaleT    28.351602  41.961728  41.089532  4.026231  33.063733
# FemaleT  27.504086  28.763621  32.213039  1.332615   5.430475

# %%
sns.distplot(df_Female['%tips'], kde=True, bins=7)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17184\2393908068.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_Female['%tips'], kde=True, bins=7)

# %%
sns.displot(data=df, x='%tips', col='sex', kde=True, bins=5)

plt.suptitle('Distribution of %tips by sex', y=1.05)
plt.show()

# %% [markdown]
# ### ON TIPS WEEKDAY, WEEKEND

# %%
smct = df_weekday['%tips'].count()
smsum = df_weekday['%tips'].sum()
smmean = df_weekday['%tips'].mean()
smsd = df_weekday['%tips'].std()
smmin = df_weekday['%tips'].min()
smq1 = df_weekday['%tips'].quantile(0.25)
smmid = df_weekday['%tips'].median()
smq3 = df_weekday['%tips'].quantile(0.75)
smmax = df_weekday['%tips'].max()
smran = df_weekday['%tips'].max() - df_weekday['%tips'].min()
smiqr = df_weekday['%tips'].quantile(0.75) - df_weekday['%tips'].quantile(0.25)
smlow = df_weekday['%tips'].quantile(0.25) - (1.5 * (df_weekday['%tips'].quantile(0.75) - df_weekday['%tips'].quantile(0.25)))
smup = df_weekday['%tips'].quantile(0.75) + (1.5 * (df_weekday['%tips'].quantile(0.75) - df_weekday['%tips'].quantile(0.25)))
smvar = df_weekday['%tips'].var()
smcoff = df_weekday['%tips'].std() / df_weekday['%tips'].mean() * 100
smskew = df_weekday['%tips'].skew()
smkurt = df_weekday['%tips'].kurtosis()

# %%
print(smct)
print(smsum)
print(smmean)
print(smsd)
print(smmin)
print(smq1)
print(smmid)
print(smq3)
print(smmax)
print(smran)
print(smiqr)
print(smlow)
print(smup)
print(smvar)
print(smcoff)
print(smskew)
print(smkurt)
# Out:
# 81
# 1322.743685186822
# 16.330168952923728
# 4.079099735891567
# 7.296137339055794
# 13.774104683195592
# 15.384615384615385
# 19.36108422071636
# 26.63115845539281
# 19.335021116337018
# 5.586979537520769
# 5.393635376914439
# 27.741553526997514
# 16.639054655350648
# 24.978919370955136
# 0.37446301071986293
# 0.05493865468538228

# %%
dmct = df_weekend['%tips'].count()
dmsum = df_weekend['%tips'].sum()
dmmean = df_weekend['%tips'].mean()
dmsd = df_weekend['%tips'].std()
dmmin = df_weekend['%tips'].min()
dmq1 = df_weekend['%tips'].quantile(0.25)
dmmid = df_weekend['%tips'].median()
dmq3 = df_weekend['%tips'].quantile(0.75)
dmmax = df_weekend['%tips'].max()
dmran = df_weekend['%tips'].max() - df_weekend['%tips'].min()
dmiqr = df_weekend['%tips'].quantile(0.75) - df_weekend['%tips'].quantile(0.25)
dmlow = df_weekend['%tips'].quantile(0.25) - (1.5 * (df_weekend['%tips'].quantile(0.75) - df_weekend['%tips'].quantile(0.25)))
dmup = df_weekend['%tips'].quantile(0.75) + (1.5 * (df_weekend['%tips'].quantile(0.75) - df_weekend['%tips'].quantile(0.25)))
dmvar = df_weekend['%tips'].var()
dmcoff = df_weekend['%tips'].std() / df_weekend['%tips'].mean() * 100
dmskew = df_weekend['%tips'].skew()
dmkurt = df_weekend['%tips'].kurtosis()

# %%
print(dmct)
print(dmsum)
print(dmmean)
print(dmsd)
print(dmmin)
print(dmq1)
print(dmmid)
print(dmq3)
print(dmmax)
print(dmran)
print(dmiqr)
print(dmlow)
print(dmup)
print(dmvar)
print(dmcoff)
print(dmskew)
print(dmkurt)
# Out:
# 163
# 2600.839308842293
# 15.95606937940057
# 6.905334821735154
# 3.563813585135547
# 12.300239310006502
# 15.558148580318942
# 18.827081506393377
# 71.0344827586207
# 67.47066917348515
# 6.526842196386875
# 2.5099760154261883
# 28.61734480097369
# 47.68364900026806
# 43.27716718661303
# 3.487808584260595
# 25.039822349231244

# %%
Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
WeekdayT = [81,1322.743685186822,16.330168952923728,4.079099735891567,7.296137339055794,13.774104683195592,15.384615384615385,19.36108422071636,26.63115845539281,19.335021116337018,5.586979537520769,5.393635376914439,27.741553526997514,16.639054655350648,24.978919370955136,0.37446301071986293,0.05493865468538228]
WeekendT =[163,2600.839308842293,15.95606937940057,6.905334821735154,3.563813585135547,12.300239310006502,15.558148580318942,18.827081506393377,71.0344827586207,67.47066917348515,6.526842196386875,2.5099760154261883,28.61734480097369,47.68364900026806,43.27716718661303,3.487808584260595,25.039822349231244]
tip3 = pd.DataFrame([Metric,WeekdayT,WeekendT]) # Each list would be added as a row
tip3 = tip3.transpose() # To Transpose and make each rows as columns
tip3.columns = ['Metric', 'WeekdayT','WeekendT'] # Rename the columns
tip3
# Out:
#    Metric     WeekdayT     WeekendT
# 0      ct           81          163
# 1     sum  1322.743685  2600.839309
# 2    mean    16.330169    15.956069
# 3      sd       4.0791     6.905335
# 4     min     7.296137     3.563814
# 5      q1    13.774105    12.300239
# 6     mid    15.384615    15.558149
# 7      q3    19.361084    18.827082
# 8     max    26.631158    71.034483
# 9     ran    19.335021    67.470669
# 10    iqr      5.58698     6.526842
# 11    low     5.393635     2.509976
# 12     up    27.741554    28.617345
# 13    var    16.639055    47.683649
# 14   coff    24.978919    43.277167
# 15   skew     0.374463     3.487809
# 16   kurt     0.054939    25.039822

# %%
tips3 = tip3.transpose()
tips3
# Out:
#            0            1          2         3         4          5   \
# Metric     ct          sum       mean        sd       min         q1
# WeekdayT   81  1322.743685  16.330169    4.0791  7.296137  13.774105
# WeekendT  163  2600.839309  15.956069  6.905335  3.563814  12.300239
#
#                  6          7          8          9         10        11  \
# Metric          mid         q3        max        ran       iqr       low
# WeekdayT  15.384615  19.361084  26.631158  19.335021   5.58698  5.393635
# WeekendT  15.558149  18.827082  71.034483  67.470669  6.526842  2.509976
#
#                  12         13         14        15         16
# Metric           up        var       coff      skew       kurt
# WeekdayT  27.741554  16.639055  24.978919  0.374463   0.054939
# WeekendT  28.617345  47.683649  43.277167  3.487809  25.039822

# %%
sns.displot(data=df, x='%tips', col='day_type', kde=True, bins=5)

plt.suptitle('Distribution of %tips by day_type', y=1.05)
plt.show()

# %%
time=df.groupby('time').describe()
time
# Out:
#        total_bill                                                              \
#             count       mean       std   min      25%     50%      75%    max
# time
# Dinner      176.0  20.797159  9.142029  3.07  14.4375  18.390  25.2825  50.81
# Lunch        68.0  17.168676  7.713882  7.51  12.2350  15.965  19.5325  43.11
#
#           tip            ...      %tips              bill                      \
#         count      mean  ...        75%        max  count      mean       std
# time                     ...
# Dinner  176.0  3.102670  ...  18.820878  71.034483  176.0  8.109560  3.075661
# Lunch    68.0  2.728088  ...  19.391734  26.631158   68.0  7.315375  2.373743
#
#
#           min      25%     50%     75%     max
# time
# Dinner  2.875  5.84875  7.5125  9.7650  20.275
# Lunch   3.755  5.71000  6.7100  8.3925  16.340
#
# [2 rows x 40 columns]

# %%
df_dinner = df[df['time'] == 'Dinner']
df_dinner.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size      %tips      bill  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673  8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159  3.446667
#
#   day_type
# 0  weekend
# 1  weekend

# %%
df_lunch = df[df['time'] == 'Lunch']
df_lunch.head(2)
# Out:
#     total_bill  tip   sex smoker   day   time  size      %tips   bill day_type
# 77       27.20  4.0  Male     No  Thur  Lunch     4  14.705882   6.80  weekday
# 78       22.76  3.0  Male     No  Thur  Lunch     2  13.181019  11.38  weekday

# %%
zmct = df_dinner['%tips'].count()
zmsum = df_dinner['%tips'].sum()
zmmean = df_dinner['%tips'].mean()
zmsd = df_dinner['%tips'].std()
zmmin = df_dinner['%tips'].min()
zmq1 = df_dinner['%tips'].quantile(0.25)
zmmid = df_dinner['%tips'].median()
zmq3 = df_dinner['%tips'].quantile(0.75)
zmmax = df_dinner['%tips'].max()
zmran = df_dinner['%tips'].max() - df_dinner['%tips'].min()
zmiqr = df_dinner['%tips'].quantile(0.75) - df_dinner['%tips'].quantile(0.25)
zmlow = df_dinner['%tips'].quantile(0.25) - (1.5 * (df_dinner['%tips'].quantile(0.75) - df_dinner['%tips'].quantile(0.25)))
zmup = df_dinner['%tips'].quantile(0.75) + (1.5 * (df_dinner['%tips'].quantile(0.75) - df_dinner['%tips'].quantile(0.25)))
zmvar = df_dinner['%tips'].var()
zmcoff = df_dinner['%tips'].std() / df_dinner['%tips'].mean() * 100
zmskew = df_dinner['%tips'].skew()
zmkurt = df_dinner['%tips'].kurtosis()

# %%
print(zmct)
print(zmsum)
print(zmmean)
print(zmsd)
print(zmmin)
print(zmq1)
print(zmmid)
print(zmq3)
print(zmmax)
print(zmran)
print(zmiqr)
print(zmlow)
print(zmup)
print(zmvar)
print(zmcoff)
print(zmskew)
print(zmkurt)
# Out:
# 176
# 2807.5130825240813
# 15.951778877977734
# 6.747713936311216
# 3.563813585135547
# 12.319151117063708
# 15.540002033246001
# 18.82087847662096
# 71.0344827586207
# 67.47066917348515
# 6.5017273595572505
# 2.566560077727832
# 28.573469515956834
# 45.531643366288606
# 42.300698799347
# 3.47844932650255
# 25.44669775900232

# %%
lmct = df_lunch['%tips'].count()
lmsum = df_lunch['%tips'].sum()
lmmean = df_lunch['%tips'].mean()
lmsd = df_lunch['%tips'].std()
lmmin = df_lunch['%tips'].min()
lmq1 = df_lunch['%tips'].quantile(0.25)
lmmid = df_lunch['%tips'].median()
lmq3 = df_lunch['%tips'].quantile(0.75)
lmmax = df_lunch['%tips'].max()
lmran = df_lunch['%tips'].max() - df_lunch['%tips'].min()
lmiqr = df_lunch['%tips'].quantile(0.75) - df_lunch['%tips'].quantile(0.25)
lmlow = df_lunch['%tips'].quantile(0.25) - (1.5 * (df_lunch['%tips'].quantile(0.75) - df_lunch['%tips'].quantile(0.25)))
lmup = df_lunch['%tips'].quantile(0.75) + (1.5 * (df_lunch['%tips'].quantile(0.75) - df_lunch['%tips'].quantile(0.25)))
lmvar = df_lunch['%tips'].var()
lmcoff = df_lunch['%tips'].std() / df_lunch['%tips'].mean() * 100
lmskew = df_lunch['%tips'].skew()
lmkurt = df_lunch['%tips'].kurtosis()

# %%
print(lmct)
print(lmsum)
print(lmmean)
print(lmsd)
print(lmmin)
print(lmq1)
print(lmmid)
print(lmq3)
print(lmmax)
print(lmran)
print(lmiqr)
print(lmlow)
print(lmup)
print(lmvar)
print(lmcoff)
print(lmskew)
print(lmkurt)
# Out:
# 68
# 1116.0699115050338
# 16.412792816250498
# 4.024154908978703
# 7.296137339055794
# 13.914665785993767
# 15.40835707502374
# 19.391733769531427
# 26.63115845539281
# 19.335021116337018
# 5.47706798353766
# 5.699063810687276
# 27.60733574483792
# 16.193822731457395
# 24.518404357083824
# 0.2259161831948613
# 0.051433642853729644

# %%
Metric = ["ct","sum","mean","sd","min","q1","mid","q3","max","ran","iqr","low","up","var","coff","skew","kurt"]
Dinner = [176,2807.5130825240813,15.951778877977734,6.747713936311216,3.563813585135547,12.319151117063708,15.540002033246001,18.82087847662096,71.0344827586207,67.47066917348515,6.5017273595572505,2.566560077727832,28.573469515956834,45.531643366288606,42.300698799347,3.47844932650255,25.44669775900232]
Lunch =[68,1116.0699115050338,16.412792816250498,4.024154908978703,7.296137339055794,13.914665785993767,15.40835707502374,19.391733769531427,26.63115845539281,19.335021116337018,5.47706798353766,5.699063810687276,27.60733574483792,16.193822731457395,24.518404357083824,0.2259161831948613,0.051433642853729644]
tip4 = pd.DataFrame([Metric,Dinner,Lunch]) # Each list would be added as a row
tip4 = tip4.transpose() # To Transpose and make each rows as columns
tip4.columns = ['Metric', 'Dinner','Lunch'] # Rename the columns
tip4
# Out:
#    Metric       Dinner        Lunch
# 0      ct          176           68
# 1     sum  2807.513083  1116.069912
# 2    mean    15.951779    16.412793
# 3      sd     6.747714     4.024155
# 4     min     3.563814     7.296137
# 5      q1    12.319151    13.914666
# 6     mid    15.540002    15.408357
# 7      q3    18.820878    19.391734
# 8     max    71.034483    26.631158
# 9     ran    67.470669    19.335021
# 10    iqr     6.501727     5.477068
# 11    low      2.56656     5.699064
# 12     up     28.57347    27.607336
# 13    var    45.531643    16.193823
# 14   coff    42.300699    24.518404
# 15   skew     3.478449     0.225916
# 16   kurt    25.446698     0.051434

# %%
sns.displot(data=df, x='%tips', col='time', kde=True, bins=5)

plt.suptitle('Distribution of %tips by time', y=1.05)
plt.show()
