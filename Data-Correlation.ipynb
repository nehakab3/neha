# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = pd.read_excel(r'C:\Users\abrahamp\OneDrive - Hewlett Packard Enterprise\Documents\Personal Stuff\Class Notes\Data Science Course\Python for Data Science\tips.xlsx')

# %%
text = pd.read_excel(r'C:\Users\abrahamp\OneDrive - Hewlett Packard Enterprise\Documents\Personal Stuff\Class Notes\Data Science Course\Python for Data Science\texting.xlsx')

# %%
cars = pd.read_excel(r'C:\Users\abrahamp\OneDrive - Hewlett Packard Enterprise\Documents\Personal Stuff\Class Notes\Data Science Course\Python for Data Science\Cars.xlsx')

# %%
print(tips.shape)
print(text.shape)
print(cars.shape)
# Out:
# (244, 7)
# (175, 2)
# (428, 15)

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
text.head(2)
# Out:
#    Males:  Females:
# 0     127       112
# 1      44       203

# %%
cars.head(2)
# Out:
#     Make            Model   Type Origin DriveTrain   MSRP  Invoice  \
# 0  Acura              MDX    SUV   Asia        All  36945    33337
# 1  Acura   RSX Type S 2dr  Sedan   Asia      Front  23820    21761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172

# %% [markdown]
# # Calculating Correlation

# %% [markdown]
# # TEXTING DATA

# %%
corr = text.corr()
corr.
# Out:
#             Males:  Females:
# Males:    1.000000  0.109778
# Females:  0.109778  1.000000

# %%
fig1 = text.plot.scatter(x='Males:',
                      y='Females:')

# %% [markdown]
# # TIPS DATA

# %%
tips = tips.drop(['sex', 'smoker', 'day', 'time', 'size'], axis=1)
tips.shape
# Out:
# (244, 2)

# %%
corrt = tips.corr()
corrt
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
corrt = tips.corr()
corrt.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0bfce_row0_col0, #T_0bfce_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0bfce_row0_col1, #T_0bfce_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0bfce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bfce_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_0bfce_level0_col1" class="col_heading level0 col1" >tip</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bfce_level0_row0" class="row_heading level0 row0" >total_bill</th>
#       <td id="T_0bfce_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0bfce_row0_col1" class="data row0 col1" >0.675734</td>
#     </tr>
#     <tr>
#       <th id="T_0bfce_level0_row1" class="row_heading level0 row1" >tip</th>
#       <td id="T_0bfce_row1_col0" class="data row1 col0" >0.675734</td>
# ...

# %% [markdown]
# # CARS DATA

# %%
cars = cars.drop(['Make','Model','Invoice','Type','Origin','DriveTrain'], axis=1)
cars.shape
# Out:
# (428, 9)

# %%
corrc = cars.corr()
corrc
# Out:
#                  MSRP  EngineSize  Cylinders  Horsepower  MPG_City  \
# MSRP         1.000000    0.571753   0.649742    0.826945 -0.475020
# EngineSize   0.571753    1.000000   0.908002    0.787435 -0.709471
# Cylinders    0.649742    0.908002   1.000000    0.810341 -0.684402
# Horsepower   0.826945    0.787435   0.810341    1.000000 -0.676699
# MPG_City    -0.475020   -0.709471  -0.684402   -0.676699  1.000000
# MPG_Highway -0.439622   -0.717302  -0.676100   -0.647195  0.941021
# Weight       0.448426    0.807867   0.742209    0.630796 -0.737966
# Wheelbase    0.152000    0.636517   0.546730    0.387398 -0.507284
# Length       0.172037    0.637448   0.547783    0.381554 -0.501526
#
#              MPG_Highway    Weight  Wheelbase    Length
# MSRP           -0.439622  0.448426   0.152000  0.172037
# EngineSize     -0.717302  0.807867   0.636517  0.637448
# Cylinders      -0.676100  0.742209   0.546730  0.547783
# Horsepower     -0.647195  0.630796   0.387398  0.381554
# ...

# %%
# Plotting correlation heatmap
dataplot = sns.heatmap(cars.corr(numeric_only=True), cmap="YlGnBu", annot=True)

# Displaying heatmap
plt.show()

# %%
heatmap = sns.heatmap(cars.corr(), vmin=-1, vmax=1, annot=True)
